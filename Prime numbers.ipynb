# %%
def is_prime(n):
    
    # Deal with special cases
    if n == 0 or n == 1:
        return False
    
    # Loop through all numbers between 2 and n - 1, and check if n is NOT prime
    i = 2
    while i < n:
        if n % i == 0:
            return False
        i = i + 1
    
    # If the program reached this point, that means the number is prime
    return True

# %%
is_prime(123)
# Out:
# False

# %%
is_prime(827)
# Out:
# True

# %% [markdown]
# Count the number of prime numbers in the range of 100 to 151, including 151

# %%
count = 0

for i in range(100, 152):
    if is_prime(i):
        count = count + 1

print(count)
# Out:
# 11

# %%
l = [326, 303, 313, 351]

for i in l:
    if is_prime(i):
        print(i)
# Out:
# 313

# %% [markdown]
# Optimizing the code

# %%
import math    # Importing this library so we can calculate square roots

def is_prime_improved(n):
    
    
    if n == 0 or n == 1:   # Deal with special cases
        return False
    
    # Loop through all numbers between 2 and the square root of n, and check if n is NOT prime
    # If n is divisible by any number greater than sqrt(n), 
    # its counterpart in the product would be a number smaller than sqrt(n),
    # and thus, we would have already checked it
    i = 2
    while i <= math.sqrt(n):
        if n % i == 0:
            return False
        i = i + 1
    
    # If the program reached this point, that means the number is prime
    return True

# %%
is_prime_improved(383)
